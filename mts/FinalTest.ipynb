# %% [markdown]
# # Desafio final
# Verificacao inicial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#port1 = 'https://drive.google.com/open?id=1hgBhk-S0jKCF-GYBz8eaaktvmkH9xI0b'
#port2 = 'https://drive.google.com/open?id=1bbSy0C981TbenfQOAhaK6Q-q-ppq1X'
#port3 = 'https://drive.google.com/open?id=18VH0WhmF3iRLk_pVwcTclUn_AiZFGYTX'

# %% [markdown]
# ## df_market = Dados do mercado global de negócios
#
# df_market possui 614MB com shape (462298, 182)

# %%
#df_port3 = pd.read_csv('https://drive.google.com/open?id=18VH0WhmF3iRLk_pVwcTclUn_AiZFGYTX')

# %%
df_market = pd.read_csv('market.csv', index_col=0)

# %%
df_market.head()
# Out:
#                                                   id  fl_matriz  \
# 0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo             setor  \
# 0                         INDUSTRIA DA CONSTRUCAO  CONSTRUÇÃO CIVIL
# ...

# %%
df_market.shape
# Out:
# (462298, 181)

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462298 entries, 0 to 462297
# Columns: 181 entries, id to qt_filiais
# dtypes: bool(9), float64(144), int64(1), object(27)
# memory usage: 614.1+ MB

# %%
list_columns = df_market.columns

# %%
pd.DataFrame(list_columns)
# Out:
#                                                  0
# 0                                               id
# 1                                        fl_matriz
# 2                             de_natureza_juridica
# 3                                            sg_uf
# 4                          natureza_juridica_macro
# 5                                          de_ramo
# 6                                            setor
# 7                               idade_empresa_anos
# 8                                    idade_emp_cat
# 9                                            fl_me
# 10                                           fl_sa
# 11                                          fl_epp
# 12                                          fl_mei
# 13                                         fl_ltda
# 14                                     dt_situacao
# 15                                  fl_st_especial
# 16                                        fl_email
# ...

# %% [markdown]
# ### Se precisar renomear alguma coluna

# %%
#movies_df.rename(columns={
#       'Runtime (Minutes)': 'Runtime', 
#       'Revenue (Millions)': 'Revenue_millions'
#   }, inplace=True)

# %%
#plt.figure(figsize=(12,6))
#sns.heatmap(df_market.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ## df1 = Dados portifolio 1, trata-se de um determinado nicho de soluções.
#
# df1 possui 736kb com shape (555, 182)

# %%
df1 = pd.read_csv('portfolio1.csv', index_col=0)
df1.head()
# Out:
#                                                   id  fl_matriz  \
# 0  dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1  32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2  a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3  6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4  f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 1          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 4  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#               de_ramo     setor  idade_empresa_anos idade_emp_cat  fl_me  \
# 0  COMERCIO VAREJISTA  COMERCIO            0.646575          <= 1  False
# ...

# %%
df1.shape
# Out:
# (555, 181)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555 entries, 0 to 554
# Columns: 181 entries, id to qt_filiais
# dtypes: bool(14), float64(142), int64(3), object(22)
# memory usage: 736.0+ KB

# %%
df1.de_ramo.unique()
# Out:
# array(['COMERCIO VAREJISTA', 'BENS DE CONSUMO'], dtype=object)

# %%
df1.setor.unique()
# Out:
# array(['COMERCIO', 'INDUSTRIA', 'SERVIÇO'], dtype=object)

# %%
plt.hist(df1.setor)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df1.groupby('setor').id.count()
# Out:
# setor
# COMERCIO     496
# INDUSTRIA     52
# SERVIÇO        7
# Name: id, dtype: int64

# %%
df1[df1.setor == 'INDUSTRIA'].head()
# Out:
#                                                    id  fl_matriz  \
# 10  d37003c6e5d299c3fcd45f36ec6c26d39770f1d52edc41...       True
# 13  fa2a153f8449584ae3f0e8252a56fa4309509506c921c3...       True
# 32  26bdeb6de15f66ce158b7ddd473860352b48e7693be2ed...      False
# 36  e5aeb8197c61261b80d66f1da4e3760e240a1f5557208a...       True
# 37  d4cb950ffc7f6de0a38403a590bff553a03185b1ec9dac...       True
#
#              de_natureza_juridica sg_uf natureza_juridica_macro  \
# 10  SOCIEDADE EMPRESARIA LIMITADA    RO  ENTIDADES EMPRESARIAIS
# 13          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 32  SOCIEDADE EMPRESARIA LIMITADA    MA  ENTIDADES EMPRESARIAIS
# 36          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 37  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#             de_ramo      setor  idade_empresa_anos idade_emp_cat  fl_me  \
# 10  BENS DE CONSUMO  INDUSTRIA            3.756164         1 a 5  False
# ...

# %%
df1.groupby(['setor','de_natureza_juridica']).id.count().to_frame()
# Out:
#                                                                id
# setor     de_natureza_juridica
# COMERCIO  EMPRESA INDIVIDUAL DE RESPONSABILIDADE LIMITADA...   11
#           EMPRESARIO INDIVIDUAL                               394
#           SOCIEDADE ANONIMA FECHADA                             1
#           SOCIEDADE EM CONTA DE PARTICIPACAO                    1
#           SOCIEDADE EMPRESARIA EM NOME COLETIVO                 1
#           SOCIEDADE EMPRESARIA LIMITADA                        88
# INDUSTRIA EMPRESA INDIVIDUAL DE RESPONSABILIDADE LIMITADA...    3
#           EMPRESARIO INDIVIDUAL                                34
#           SOCIEDADE EMPRESARIA LIMITADA                        15
# SERVIÇO   EMPRESA INDIVIDUAL DE RESPONSABILIDADE LIMITADA...    1
#           EMPRESARIO INDIVIDUAL                                 4
#           SOCIEDADE EMPRESARIA LIMITADA                         2

# %%
df1.idade_emp_cat.unique()
# Out:
# array(['<= 1', '5 a 10', '> 20', '15 a 20', '1 a 5', '10 a 15'],
#       dtype=object)

# %%
df1.idade_empresa_anos.head(10)
# Out:
# 0     0.646575
# 1     6.586301
# 2     8.010959
# 3    20.863014
# 4    18.726027
# 5     6.238356
# 6     9.663014
# 7     0.495890
# 8     1.161644
# 9     5.309589
# Name: idade_empresa_anos, dtype: float64

# %%
df1.idade_empresa_anos.hist()

# %%
sns.boxplot(df1.idade_empresa_anos)

# %%
sns.boxplot(x='idade_empresa_anos', y='setor', data=df1)

# %%
# criating boxplot grapichs
# link: https://www.kaggle.com/kernels/scriptcontent/20457574/download
for c in categorical_features:
    train[c] = train[c].astype('category')
    if train[c].isnull().any():
        train[c] = train[c].cat.add_categories(['MISSING'])
        train[c] = train[c].fillna('MISSING')

def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
f = pd.melt(train, id_vars=['SalePrice'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "SalePrice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-106d45d21b19> in <module>
#       1 # criating boxplot grapichs
#       2 for c in categorical_features:
# ----> 3     train[c] = train[c].astype('category')
#       4     if train[c].isnull().any():
#       5         train[c] = train[c].cat.add_categories(['MISSING'])
#
# NameError: name 'train' is not defined

# %%
total = numeric_features.isnull().sum().sort_values(ascending=False)
percent = (numeric_features.isnull().sum()/numeric_features.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1,join='outer', keys=['Total Missing Count', '% of Total Observations'])
missing_data.index.name =' Numeric Feature'

missing_data.head(20)
# Out:
#                                    Total Missing Count  \
#  Numeric Feature
# coligada_mais_antiga_baixada                       555
# idade_media_coligadas_baixadas                     555
# qt_alteracao_socio_365d                            555
# qt_alteracao_socio_180d                            555
# qt_alteracao_socio_90d                             555
# qt_alteracao_socio_total                           555
# grau_instrucao_macro_desconhecido                  555
# vl_total_veiculos_antt_grupo                       555
# vl_total_tancagem_grupo                            555
# vl_total_tancagem                                  555
# vl_total_veiculos_antt                             555
# coligada_mais_nova_baixada                         555
# grau_instrucao_macro_analfabeto                    554
# vl_idade_media_socios_pj                           553
# qt_socios_pj_suspensos                             553
# qt_socios_pj_inaptos                               553
# ...

# %%
missing_values = numeric_features.isnull().sum(axis=0).reset_index()
missing_values.columns = ['column_name', 'missing_count']
missing_values = missing_values.loc[missing_values['missing_count']>0]
missing_values = missing_values.sort_values(by='missing_count')

ind = np.arange(missing_values.shape[0])
width = 0.1
fig, ax = plt.subplots(figsize=(12,3))
rects = ax.barh(ind, missing_values.missing_count.values, color='b')
ax.set_yticks(ind)
ax.set_yticklabels(missing_values.column_name.values, rotation='horizontal')
ax.set_xlabel("Missing Observations Count")
ax.set_title("Missing Observations Count - Numeric Features")
plt.show()

# %%
import missingno as msno
msno.matrix(df1.sample(250))

# %%
msno.bar(df1)

# %%
msno.dendrogram(df1)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#df1.isnull().sum()

# %%
# checkin what is numerical
numeric_features = df1.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['idade_empresa_anos', 'vl_total_tancagem', 'vl_total_veiculos_antt',
#        'vl_total_veiculos_leves', 'vl_total_veiculos_pesados', 'qt_art',
#        'vl_total_veiculos_pesados_grupo', 'vl_total_veiculos_leves_grupo',
#        'vl_total_tancagem_grupo', 'vl_total_veiculos_antt_grupo',
#        ...
#        'media_meses_servicos', 'max_meses_servicos', 'min_meses_servicos',
#        'qt_funcionarios', 'qt_funcionarios_12meses', 'qt_funcionarios_24meses',
#        'tx_crescimento_12meses', 'tx_crescimento_24meses', 'tx_rotatividade',
#        'qt_filiais'],
#       dtype='object', length=145)

# %%
# checkin what is categorical
categorical_features = df1.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['id', 'de_natureza_juridica', 'sg_uf', 'natureza_juridica_macro',
#        'de_ramo', 'setor', 'idade_emp_cat', 'dt_situacao', 'fl_rm',
#        'nm_divisao', 'nm_segmento', 'fl_optante_simples', 'fl_optante_simei',
#        'sg_uf_matriz', 'de_saude_tributaria', 'de_saude_rescencia',
#        'de_nivel_atividade', 'de_indicador_telefone', 'nm_meso_regiao',
#        'nm_micro_regiao', 'de_faixa_faturamento_estimado',
#        'de_faixa_faturamento_estimado_grupo'],
#       dtype='object')

# %% [markdown]
# ## df2 = Dados portifolio 2, trata-se de um determinado nicho de soluções.
#
# df1 de shape (566, 2) incompleto, necessita preenchimento a partir dos dados do df_market

# %%
df2 = pd.read_csv('portfolio2.csv', index_col=0)
df2.head()
# Out:
#                                                   id
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...

# %%
df22 = pd.merge(df2, df_market, how='left', on=['id'])
df22.head()
# Out:
#                                                   id  fl_matriz  \
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...       True
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...       True
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...       True
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...       True
#
#                         de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL    AC   ADMINISTRACAO PUBLICA
# 1                                  MUNICIPIO    RN                  OUTROS
# 2                 SOCIEDADE SIMPLES LIMITADA    PI  ENTIDADES EMPRESARIAIS
# 3                                  MUNICIPIO    AM                  OUTROS
# 4              SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#                                              de_ramo         setor  \
# ...

# %%
df22.shape
# Out:
# (566, 181)

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566 entries, 0 to 565
# Columns: 181 entries, id to qt_filiais
# dtypes: bool(9), float64(144), int64(1), object(27)
# memory usage: 770.0+ KB

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df22.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ## df3 = Dados portifolio 3, trata-se de um determinado nicho de soluções.
#
# df1 de shape (265, 2) incompleto, necessita preenchimento a partir dos dados do df_market

# %%
df3 = pd.read_csv('portfolio3.csv', index_col=0)
df3.head()
# Out:
#                                                   id
# 0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...
# 1  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...
# 3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...
# 4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...

# %%
df3.shape
# Out:
# (265, 1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 265 entries, 0 to 264
# Data columns (total 1 columns):
# id    265 non-null object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
df33 = pd.merge(df3, df_market, how='left', on=['id'])
df33.head()
# Out:
#                                                   id  fl_matriz  \
# 0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...       True
# 1  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...       True
# 3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...       True
# 4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...       True
#
#                                 de_natureza_juridica sg_uf  \
# 0                                          MUNICIPIO    MA
# 1                         SOCIEDADE SIMPLES LIMITADA    PI
# 2  ORGAO PUBLICO DO PODER EXECUTIVO ESTADUAL OU D...    AM
# 3                                          MUNICIPIO    PI
# 4                                          MUNICIPIO    RN
#
#   natureza_juridica_macro                                            de_ramo  \
# 0                  OUTROS  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df33.isnull(),yticklabels=False,cbar=False,cmap='viridis')

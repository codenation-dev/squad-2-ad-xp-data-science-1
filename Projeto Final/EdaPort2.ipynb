# %% [markdown]
# ## Preenchimento dos dados NaN + EDA (Exploratory Data Analysis)
# Criar arquivos "marketok", "portifolio1ok", "portifolio2ok" e "portifolio3ok" com os features que possuem menos de 32% de dados faltantes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import missingno as msno

# %% [markdown]
# ## Dados de Portifolio, trata-se de um determinado nicho de soluções.

# %%
df = pd.read_csv('portfolio2ok.csv', index_col=0)
df.head()
# Out:
#                                                   id  fl_matriz  \
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...       True
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...       True
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...       True
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...       True
#
#                         de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL    AC   ADMINISTRACAO PUBLICA
# 1                                  MUNICIPIO    RN                  OUTROS
# 2                 SOCIEDADE SIMPLES LIMITADA    PI  ENTIDADES EMPRESARIAIS
# 3                                  MUNICIPIO    AM                  OUTROS
# 4              SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#                                              de_ramo         setor  \
# 0  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 1  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 2                               SERVICOS DE EDUCACAO       SERVIÇO
# 3  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 4                           PRODUTOS DE AGROPECUARIA  AGROPECUARIA
#
#    idade_empresa_anos idade_emp_cat  fl_me    ...      \
# 0           11.243836       10 a 15  False    ...
# 1           43.789041          > 20  False    ...
# 2           16.389041       15 a 20  False    ...
# 3           39.671233          > 20  False    ...
# 4           20.268493          > 20  False    ...
#
#             nm_micro_regiao  fl_passivel_iss  qt_socios  qt_socios_pf  \
# 0                RIO BRANCO             True        NaN           NaN
# 1          AGRESTE POTIGUAR             True        NaN           NaN
# 2  BAIXO PARNAIBA PIAUIENSE             True        2.0           2.0
# 3             ALTO SOLIMOES             True        NaN           NaN
# 4                   MOSSORO             True        4.0           4.0
#
#   qt_socios_pj             de_faixa_faturamento_estimado  \
# 0          NaN  DE R$ 300.000.000,01 A R$ 500.000.000,00
# 1          NaN  DE R$ 100.000.000,01 A R$ 300.000.000,00
# 2          0.0    DE R$ 10.000.000,01 A R$ 30.000.000,00
# 3          NaN  DE R$ 100.000.000,01 A R$ 300.000.000,00
# 4          0.0    DE R$ 10.000.000,01 A R$ 30.000.000,00
#
#         de_faixa_faturamento_estimado_grupo  vl_faturamento_estimado_aux  \
# 0  DE R$ 300.000.000,01 A R$ 500.000.000,00                  327487200.0
# 1  DE R$ 100.000.000,01 A R$ 300.000.000,00                  176802910.0
# 2    DE R$ 10.000.000,01 A R$ 30.000.000,00                   27818640.0
# 3  DE R$ 100.000.000,01 A R$ 300.000.000,00                  221518800.0
# 4    DE R$ 10.000.000,01 A R$ 30.000.000,00                   28127736.0
#
#   vl_faturamento_estimado_grupo_aux qt_filiais
# 0                       327487200.0          0
# 1                       176802910.0          0
# 2                        27818640.0          0
# 3                       221518800.0          1
# 4                        28127736.0          0
#
# [5 rows x 46 columns]

# %%
# removendo 'qt_socios_pj', 'qt_socios_pf', 'qt_socios', pois há muitos dados faltantes, 
#não há como prever seu campo e influenciam pouco no mercado.
df = df.drop(columns=['qt_socios_pj', 'qt_socios_pf', 'qt_socios'])
df.head()
# Out:
#                                                   id  fl_matriz  \
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...       True
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...       True
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...       True
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...       True
#
#                         de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL    AC   ADMINISTRACAO PUBLICA
# 1                                  MUNICIPIO    RN                  OUTROS
# 2                 SOCIEDADE SIMPLES LIMITADA    PI  ENTIDADES EMPRESARIAIS
# 3                                  MUNICIPIO    AM                  OUTROS
# 4              SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#                                              de_ramo         setor  \
# 0  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 1  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 2                               SERVICOS DE EDUCACAO       SERVIÇO
# 3  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 4                           PRODUTOS DE AGROPECUARIA  AGROPECUARIA
#
#    idade_empresa_anos idade_emp_cat  fl_me    ...      fl_simples_irregular  \
# 0           11.243836       10 a 15  False    ...                     False
# 1           43.789041          > 20  False    ...                     False
# 2           16.389041       15 a 20  False    ...                     False
# 3           39.671233          > 20  False    ...                     False
# 4           20.268493          > 20  False    ...                     False
#
#    empsetorcensitariofaixarendapopulacao       nm_meso_regiao  \
# 0                                2791.15         VALE DO ACRE
# 1                                1007.87     AGRESTE POTIGUAR
# 2                                 688.31      NORTE PIAUIENSE
# 3                                1397.47  SUDOESTE AMAZONENSE
# 4                                 707.20       OESTE POTIGUAR
#
#             nm_micro_regiao fl_passivel_iss  \
# 0                RIO BRANCO            True
# 1          AGRESTE POTIGUAR            True
# 2  BAIXO PARNAIBA PIAUIENSE            True
# 3             ALTO SOLIMOES            True
# 4                   MOSSORO            True
#
#               de_faixa_faturamento_estimado  \
# 0  DE R$ 300.000.000,01 A R$ 500.000.000,00
# 1  DE R$ 100.000.000,01 A R$ 300.000.000,00
# 2    DE R$ 10.000.000,01 A R$ 30.000.000,00
# 3  DE R$ 100.000.000,01 A R$ 300.000.000,00
# 4    DE R$ 10.000.000,01 A R$ 30.000.000,00
#
#         de_faixa_faturamento_estimado_grupo  vl_faturamento_estimado_aux  \
# 0  DE R$ 300.000.000,01 A R$ 500.000.000,00                  327487200.0
# 1  DE R$ 100.000.000,01 A R$ 300.000.000,00                  176802910.0
# 2    DE R$ 10.000.000,01 A R$ 30.000.000,00                   27818640.0
# 3  DE R$ 100.000.000,01 A R$ 300.000.000,00                  221518800.0
# 4    DE R$ 10.000.000,01 A R$ 30.000.000,00                   28127736.0
#
#   vl_faturamento_estimado_grupo_aux qt_filiais
# 0                       327487200.0          0
# 1                       176802910.0          0
# 2                        27818640.0          0
# 3                       221518800.0          1
# 4                        28127736.0          0
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (566, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566 entries, 0 to 565
# Data columns (total 43 columns):
# id                                       566 non-null object
# fl_matriz                                566 non-null bool
# de_natureza_juridica                     566 non-null object
# sg_uf                                    566 non-null object
# natureza_juridica_macro                  566 non-null object
# de_ramo                                  566 non-null object
# setor                                    566 non-null object
# idade_empresa_anos                       566 non-null float64
# idade_emp_cat                            566 non-null object
# fl_me                                    566 non-null bool
# fl_sa                                    566 non-null bool
# fl_epp                                   566 non-null bool
# fl_mei                                   566 non-null bool
# fl_ltda                                  566 non-null bool
# dt_situacao                              566 non-null object
# fl_st_especial                           566 non-null bool
# fl_email                                 566 non-null bool
# fl_telefone                              566 non-null bool
# fl_rm                                    566 non-null object
# nm_divisao                               566 non-null object
# nm_segmento                              566 non-null object
# fl_spa                                   566 non-null bool
# fl_antt                                  566 non-null bool
# fl_veiculo                               566 non-null bool
# fl_optante_simples                       566 non-null bool
# vl_total_veiculos_pesados_grupo          566 non-null float64
# vl_total_veiculos_leves_grupo            566 non-null float64
# fl_optante_simei                         566 non-null bool
# sg_uf_matriz                             566 non-null object
# de_saude_tributaria                      566 non-null object
# de_saude_rescencia                       566 non-null object
# nu_meses_rescencia                       566 non-null float64
# de_nivel_atividade                       566 non-null object
# fl_simples_irregular                     566 non-null bool
# empsetorcensitariofaixarendapopulacao    496 non-null float64
# nm_meso_regiao                           496 non-null object
# nm_micro_regiao                          496 non-null object
# fl_passivel_iss                          566 non-null bool
# de_faixa_faturamento_estimado            566 non-null object
# de_faixa_faturamento_estimado_grupo      566 non-null object
# vl_faturamento_estimado_aux              566 non-null float64
# vl_faturamento_estimado_grupo_aux        566 non-null float64
# qt_filiais                               566 non-null int64
# dtypes: bool(16), float64(7), int64(1), object(19)
# memory usage: 132.7+ KB

# %% [markdown]
# # Avaliação de dados faltantes

# %% [markdown]
# ### Percebe-se que este portifolio possui um elevado número de dados faltantes.

# %%
# plot dados faltantes geral
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# plot dados faltantes geral
msno.matrix(df)

# %%
# plot dados faltantes geral
msno.bar(df)

# %%
# checkin what is numerical features
num_feat = df.select_dtypes(include=[np.number])
num_feat.columns
# Out:
# Index(['idade_empresa_anos', 'vl_total_veiculos_pesados_grupo',
#        'vl_total_veiculos_leves_grupo', 'nu_meses_rescencia',
#        'empsetorcensitariofaixarendapopulacao', 'vl_faturamento_estimado_aux',
#        'vl_faturamento_estimado_grupo_aux', 'qt_filiais'],
#       dtype='object')

# %%
# checkin what is categorical features
cat_feat = df.select_dtypes(include=[np.object])
cat_feat.columns
# Out:
# Index(['id', 'de_natureza_juridica', 'sg_uf', 'natureza_juridica_macro',
#        'de_ramo', 'setor', 'idade_emp_cat', 'dt_situacao', 'fl_rm',
#        'nm_divisao', 'nm_segmento', 'sg_uf_matriz', 'de_saude_tributaria',
#        'de_saude_rescencia', 'de_nivel_atividade', 'nm_meso_regiao',
#        'nm_micro_regiao', 'de_faixa_faturamento_estimado',
#        'de_faixa_faturamento_estimado_grupo'],
#       dtype='object')

# %%
# plot dados faltantes para os features numericos
msno.matrix(num_feat)

# %%
# plot dados faltantes para os features numericos
msno.bar(num_feat)

# %%
# plot dados faltantes para os features categoricos
msno.matrix(cat_feat)

# %%
# plot dados faltantes para os features categoricos
msno.bar(cat_feat)

# %% [markdown]
# ## Quantificando dados faltantes
# #### entre numericos e categoricos

# %%
total_num_feat = num_feat.isnull().sum().sort_values(ascending=False)
total_num_feat.sum()
# Out:
# 70

# %%
percent_num_feat = (num_feat.isnull().sum()/num_feat.isnull().count()).sort_values(ascending=False)
round(percent_num_feat.sum(), 2)
# Out:
# 0.12

# %%
missing_data_num_feat = pd.concat([total_num_feat, percent_num_feat], axis=1,join='outer', keys=['Total_Missing_Count', 'Percent_of_Missing'])
missing_data_num_feat.index.name ='features'
missing_data_num_feat.head(5)
# Out:
#                                        Total_Missing_Count  Percent_of_Missing
# features
# empsetorcensitariofaixarendapopulacao                   70            0.123675
# qt_filiais                                               0            0.000000
# vl_faturamento_estimado_grupo_aux                        0            0.000000
# vl_faturamento_estimado_aux                              0            0.000000
# nu_meses_rescencia                                       0            0.000000

# %%
total_cat_feat = cat_feat.isnull().sum().sort_values(ascending=False)
total_cat_feat.sum()
# Out:
# 140

# %%
percent_cat_feat = (cat_feat.isnull().sum()/cat_feat.isnull().count()).sort_values(ascending=False)
round(percent_cat_feat.sum(), 2)
# Out:
# 0.25

# %%
missing_data_cat_feat = pd.concat([total_cat_feat, percent_cat_feat], axis=1,join='outer', keys=['Total_Missing_Count', 'Percent_of_Missing'])
missing_data_cat_feat.index.name ='features'
missing_data_cat_feat.head(4)
# Out:
#                                      Total_Missing_Count  Percent_of_Missing
# features
# nm_micro_regiao                                       70            0.123675
# nm_meso_regiao                                        70            0.123675
# de_faixa_faturamento_estimado_grupo                    0            0.000000
# dt_situacao                                            0            0.000000

# %% [markdown]
# # Preenchendo dados faltantes

# %% [markdown]
# #### Itens que serão preenchidos - Categóricos

# %%
# nm_micro_regiao	64	0.115315
# inferir utilizando este campo e estado (sg_uf)

# %%
# nm_meso_regiao	64	0.115315
# inferir utilizando este campo e estado (sg_uf)

# %% [markdown]
# # Avaliação do contexto

# %%
df.columns
# Out:
# Index(['id', 'fl_matriz', 'de_natureza_juridica', 'sg_uf',
#        'natureza_juridica_macro', 'de_ramo', 'setor', 'idade_empresa_anos',
#        'idade_emp_cat', 'fl_me', 'fl_sa', 'fl_epp', 'fl_mei', 'fl_ltda',
#        'dt_situacao', 'fl_st_especial', 'fl_email', 'fl_telefone', 'fl_rm',
#        'nm_divisao', 'nm_segmento', 'fl_spa', 'fl_antt', 'fl_veiculo',
#        'fl_optante_simples', 'vl_total_veiculos_pesados_grupo',
#        'vl_total_veiculos_leves_grupo', 'fl_optante_simei', 'sg_uf_matriz',
#        'de_saude_tributaria', 'de_saude_rescencia', 'nu_meses_rescencia',
#        'de_nivel_atividade', 'fl_simples_irregular',
#        'empsetorcensitariofaixarendapopulacao', 'nm_meso_regiao',
#        'nm_micro_regiao', 'fl_passivel_iss', 'de_faixa_faturamento_estimado',
#        'de_faixa_faturamento_estimado_grupo', 'vl_faturamento_estimado_aux',
#        'vl_faturamento_estimado_grupo_aux', 'qt_filiais'],
#       dtype='object')

# %% [raw]
# #### Principais elementos do DataFrame
# (['de_natureza_juridica', 'sg_uf',
#        'de_ramo', 'setor', 'idade_emp_cat', 'fl_me',
#        'fl_sa', 'fl_epp', 'fl_mei', 'fl_ltda', 'dt_situacao', 'fl_st_especial',
#        'fl_email', 'fl_telefone', 'fl_rm', 'nm_divisao', 'nm_segmento',
#        'fl_spa', 'fl_antt', 'fl_veiculo', 'fl_optante_simples',
#        'vl_total_veiculos_pesados_grupo', 'vl_total_veiculos_leves_grupo',
#        'fl_optante_simei', 'sg_uf_matriz', 'de_saude_tributaria',
#        'de_saude_rescencia', 'nu_meses_rescencia', 'de_nivel_atividade',
#        'fl_simples_irregular', 'empsetorcensitariofaixarendapopulacao',
#        'nm_meso_regiao', 'nm_micro_regiao', 'fl_passivel_iss',
#        'de_faixa_faturamento_estimado', 'de_faixa_faturamento_estimado_grupo',
#        'vl_faturamento_estimado_aux', 'vl_faturamento_estimado_grupo_aux',
#        'qt_filiais'],
#       dtype='object')
#
# #### Elementos menos importantes, sugestão de remoção !!
# 'fl_matriz'
# 'natureza_juridica_macro' - já está no natureza_juridica
# 'idade_empresa_anos' - já está no 'idade_emp_cat'
# 'fl_epp' - todos são False

# %%
df.fl_epp.unique()
# Out:
# array([False])

# %%
df.de_ramo.unique()
# Out:
# array(['ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL',
#        'SERVICOS DE EDUCACAO', 'PRODUTOS DE AGROPECUARIA',
#        'SERVICOS ADMINISTRATIVOS', 'COMERCIO POR ATACADO',
#        'COMERCIO VAREJISTA', 'INDUSTRIA DA CONSTRUCAO',
#        'SERVICOS PROFISSIONAIS, TECNICOS E CIENTIFICOS',
#        'QUIMICA-PETROQUIMICA', 'SERVICOS DE SANEAMENTO BASICO',
#        'COMERCIO E REPARACAO DE VEICULOS',
#        'SERVICOS DE ALOJAMENTO/ALIMENTACAO',
#        'TRANSPORTE, ARMAZENAGEM E CORREIO', 'SERVICOS DE SAUDE',
#        'TELECOM', 'SERVICOS DIVERSOS', 'BENS DE CONSUMO',
#        'SEGUROS, PLANOS DE PREVIDENCIA E PLANOS DE SAUDE',
#        'INDUSTRIA AUTOMOTIVA', 'PAPEL E CELULOSE', 'ELETROELETRONICOS',
#        'INDUSTRIA DIGITAL', 'SIDERURGICA-METALURGIA',
#        'INDUSTRIAS EXTRATIVAS', 'ATIVIDADES IMOBILIARIAS',
#        'ELETRICIDADE E GAS', 'TEXTEIS', 'SERVICOS FINANCEIROS',
#        'CULTURA, ESPORTE E RECREACAO'], dtype=object)

# %%
df.setor.unique()
# Out:
# array(['SERVIÇO', 'AGROPECUARIA', 'COMERCIO', 'CONSTRUÇÃO CIVIL',
#        'INDUSTRIA'], dtype=object)

# %%
setores = pd.DataFrame(df.groupby('setor').count())
setores
# Out:
#                    id  fl_matriz  de_natureza_juridica  sg_uf  \
# setor
# AGROPECUARIA        8          8                     8      8
# COMERCIO          107        107                   107    107
# CONSTRUÇÃO CIVIL   46         46                    46     46
# INDUSTRIA          69         69                    69     69
# SERVIÇO           336        336                   336    336
#
#                   natureza_juridica_macro  de_ramo  idade_empresa_anos  \
# setor
# AGROPECUARIA                            8        8                   8
# COMERCIO                              107      107                 107
# CONSTRUÇÃO CIVIL                       46       46                  46
# INDUSTRIA                              69       69                  69
# SERVIÇO                               336      336                 336
#
#                   idade_emp_cat  fl_me  fl_sa     ...      \
# setor                                             ...
# AGROPECUARIA                  8      8      8     ...
# COMERCIO                    107    107    107     ...
# CONSTRUÇÃO CIVIL             46     46     46     ...
# INDUSTRIA                    69     69     69     ...
# SERVIÇO                     336    336    336     ...
#
#                   fl_simples_irregular  empsetorcensitariofaixarendapopulacao  \
# setor
# AGROPECUARIA                         8                                      5
# COMERCIO                           107                                     94
# CONSTRUÇÃO CIVIL                    46                                     43
# INDUSTRIA                           69                                     64
# SERVIÇO                            336                                    290
#
#                   nm_meso_regiao  nm_micro_regiao  fl_passivel_iss  \
# setor
# AGROPECUARIA                   8                8                8
# COMERCIO                      88               88              107
# CONSTRUÇÃO CIVIL              39               39               46
# INDUSTRIA                     60               60               69
# SERVIÇO                      301              301              336
#
#                   de_faixa_faturamento_estimado  \
# setor
# AGROPECUARIA                                  8
# COMERCIO                                    107
# CONSTRUÇÃO CIVIL                             46
# INDUSTRIA                                    69
# SERVIÇO                                     336
#
#                   de_faixa_faturamento_estimado_grupo  \
# setor
# AGROPECUARIA                                        8
# COMERCIO                                          107
# CONSTRUÇÃO CIVIL                                   46
# INDUSTRIA                                          69
# SERVIÇO                                           336
#
#                   vl_faturamento_estimado_aux  \
# setor
# AGROPECUARIA                                8
# COMERCIO                                  107
# CONSTRUÇÃO CIVIL                           46
# INDUSTRIA                                  69
# SERVIÇO                                   336
#
#                   vl_faturamento_estimado_grupo_aux  qt_filiais
# setor
# AGROPECUARIA                                      8           8
# COMERCIO                                        107         107
# CONSTRUÇÃO CIVIL                                 46          46
# INDUSTRIA                                        69          69
# SERVIÇO                                         336         336
#
# [5 rows x 42 columns]

# %%
temp = pd.DataFrame({'setor':setores.index,'Qtde':setores.fl_matriz})
sns.barplot(x='Qtde',y="setor", data=temp, color="c");

# %%
df.de_natureza_juridica.unique()
# Out:
# array(['AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL', 'MUNICIPIO',
#        'SOCIEDADE SIMPLES LIMITADA', 'SOCIEDADE EMPRESARIA LIMITADA',
#        'CONDOMINIO EDILICIO',
#        'EMPRESA INDIVIDUAL DE RESPONSABILIDADE LIMITADA DE NATUREZA EMPRESARIA',
#        'ASSOCIACAO PRIVADA',
#        'ORGAO PUBLICO DO PODER EXECUTIVO ESTADUAL OU DO DISTRITO FEDERAL',
#        'SOCIEDADE ANONIMA FECHADA',
#        'ORGAO PUBLICO DO PODER LEGISLATIVO ESTADUAL OU DO DISTRITO FEDERAL',
#        'ORGAO PUBLICO DO PODER EXECUTIVO MUNICIPAL', 'FUNDACAO PRIVADA',
#        'FUNDO PUBLICO', 'ENTIDADE SINDICAL', 'EMPRESARIO INDIVIDUAL',
#        'COOPERATIVA', 'AUTARQUIA MUNICIPAL', 'AUTARQUIA FEDERAL',
#        'SOCIEDADE DE ECONOMIA MISTA',
#        'ORGAO PUBLICO DO PODER LEGISLATIVO MUNICIPAL',
#        'SERVICO SOCIAL AUTONOMO', 'SOCIEDADE ANONIMA ABERTA',
#        'FUNDACAO PUBLICA DE DIREITO PUB MUNICIPAL',
#        'ORGANIZACAO RELIGIOSA',
#        'ORGAO PUBLICO DO PODER JUDICIARIO FEDERAL',
#        'ORGAO PUBLICO DO PODER EXECUTIVO FEDERAL'], dtype=object)

# %%
#df.groupby(['setor','de_natureza_juridica']).count().to_frame()

# %%
df.idade_emp_cat.unique()
# Out:
# array(['10 a 15', '> 20', '15 a 20'], dtype=object)

# %%
df.idade_empresa_anos.head(10)
# Out:
# 0    11.243836
# 1    43.789041
# 2    16.389041
# 3    39.671233
# 4    20.268493
# 5    20.030137
# 6    18.906849
# 7    21.947945
# 8    19.610959
# 9    43.854795
# Name: idade_empresa_anos, dtype: float64

# %%
df.idade_empresa_anos.mean()
# Out:
# 26.98769059489812

# %%
df.idade_empresa_anos.hist()

# %%
sns.boxplot(df.idade_empresa_anos)

# %%
sns.boxplot(x='idade_empresa_anos', y='setor', data=df)

# %%
de_faixa_fatur_est = pd.DataFrame(df.groupby('de_faixa_faturamento_estimado').count())
de_faixa_fatur_est
# Out:
#                                            id  fl_matriz  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                  5          5
# DE R$ 10.000.000,01 A R$ 30.000.000,00    278        278
# DE R$ 100.000.000,01 A R$ 300.000.000,00   58         58
# DE R$ 30.000.000,01 A R$ 100.000.000,00   202        202
# DE R$ 300.000.000,01 A R$ 500.000.000,00   15         15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS    8          8
#
#                                           de_natureza_juridica  sg_uf  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                   5      5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     278    278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                    58     58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                    202    202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                    15     15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                     8      8
#
#                                           natureza_juridica_macro  de_ramo  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                      5        5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                        278      278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                       58       58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                       202      202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                       15       15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                        8        8
#
#                                           setor  idade_empresa_anos  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                    5                   5
# DE R$ 10.000.000,01 A R$ 30.000.000,00      278                 278
# DE R$ 100.000.000,01 A R$ 300.000.000,00     58                  58
# DE R$ 30.000.000,01 A R$ 100.000.000,00     202                 202
# DE R$ 300.000.000,01 A R$ 500.000.000,00     15                  15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS      8                   8
#
#                                           idade_emp_cat  fl_me     ...      \
# de_faixa_faturamento_estimado                                      ...
# ACIMA DE 1 BILHAO DE REAIS                            5      5     ...
# DE R$ 10.000.000,01 A R$ 30.000.000,00              278    278     ...
# DE R$ 100.000.000,01 A R$ 300.000.000,00             58     58     ...
# DE R$ 30.000.000,01 A R$ 100.000.000,00             202    202     ...
# DE R$ 300.000.000,01 A R$ 500.000.000,00             15     15     ...
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS              8      8     ...
#
#                                           de_nivel_atividade  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                 5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                   278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                  58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                  202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                  15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                   8
#
#                                           fl_simples_irregular  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                   5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                    58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                    202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                    15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                     8
#
#                                           empsetorcensitariofaixarendapopulacao  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                    5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                      241
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                     56
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                     172
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                     14
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                      8
#
#                                           nm_meso_regiao  nm_micro_regiao  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                             5                5
# DE R$ 10.000.000,01 A R$ 30.000.000,00               229              229
# DE R$ 100.000.000,01 A R$ 300.000.000,00              55               55
# DE R$ 30.000.000,01 A R$ 100.000.000,00              185              185
# DE R$ 300.000.000,01 A R$ 500.000.000,00              14               14
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS               8                8
#
#                                           fl_passivel_iss  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                              5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                278
# DE R$ 100.000.000,01 A R$ 300.000.000,00               58
# DE R$ 30.000.000,01 A R$ 100.000.000,00               202
# DE R$ 300.000.000,01 A R$ 500.000.000,00               15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                8
#
#                                           de_faixa_faturamento_estimado_grupo  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                  5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                    278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                   58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                   202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                   15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                    8
#
#                                           vl_faturamento_estimado_aux  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                          5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                            278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                           58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                           202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                           15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                            8
#
#                                           vl_faturamento_estimado_grupo_aux  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                  278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                 58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                 202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                 15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                  8
#
#                                           qt_filiais
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                         5
# DE R$ 10.000.000,01 A R$ 30.000.000,00           278
# DE R$ 100.000.000,01 A R$ 300.000.000,00          58
# DE R$ 30.000.000,01 A R$ 100.000.000,00          202
# DE R$ 300.000.000,01 A R$ 500.000.000,00          15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS           8
#
# [6 rows x 42 columns]

# %%
de_faixa_fatur_est = pd.DataFrame(df.groupby('de_faixa_faturamento_estimado').count())
de_faixa_fatur_est
# Out:
#                                            id  fl_matriz  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                  5          5
# DE R$ 10.000.000,01 A R$ 30.000.000,00    278        278
# DE R$ 100.000.000,01 A R$ 300.000.000,00   58         58
# DE R$ 30.000.000,01 A R$ 100.000.000,00   202        202
# DE R$ 300.000.000,01 A R$ 500.000.000,00   15         15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS    8          8
#
#                                           de_natureza_juridica  sg_uf  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                   5      5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     278    278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                    58     58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                    202    202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                    15     15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                     8      8
#
#                                           natureza_juridica_macro  de_ramo  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                      5        5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                        278      278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                       58       58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                       202      202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                       15       15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                        8        8
#
#                                           setor  idade_empresa_anos  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                    5                   5
# DE R$ 10.000.000,01 A R$ 30.000.000,00      278                 278
# DE R$ 100.000.000,01 A R$ 300.000.000,00     58                  58
# DE R$ 30.000.000,01 A R$ 100.000.000,00     202                 202
# DE R$ 300.000.000,01 A R$ 500.000.000,00     15                  15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS      8                   8
#
#                                           idade_emp_cat  fl_me     ...      \
# de_faixa_faturamento_estimado                                      ...
# ACIMA DE 1 BILHAO DE REAIS                            5      5     ...
# DE R$ 10.000.000,01 A R$ 30.000.000,00              278    278     ...
# DE R$ 100.000.000,01 A R$ 300.000.000,00             58     58     ...
# DE R$ 30.000.000,01 A R$ 100.000.000,00             202    202     ...
# DE R$ 300.000.000,01 A R$ 500.000.000,00             15     15     ...
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS              8      8     ...
#
#                                           de_nivel_atividade  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                 5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                   278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                  58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                  202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                  15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                   8
#
#                                           fl_simples_irregular  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                   5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                    58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                    202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                    15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                     8
#
#                                           empsetorcensitariofaixarendapopulacao  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                    5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                      241
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                     56
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                     172
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                     14
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                      8
#
#                                           nm_meso_regiao  nm_micro_regiao  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                             5                5
# DE R$ 10.000.000,01 A R$ 30.000.000,00               229              229
# DE R$ 100.000.000,01 A R$ 300.000.000,00              55               55
# DE R$ 30.000.000,01 A R$ 100.000.000,00              185              185
# DE R$ 300.000.000,01 A R$ 500.000.000,00              14               14
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS               8                8
#
#                                           fl_passivel_iss  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                              5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                278
# DE R$ 100.000.000,01 A R$ 300.000.000,00               58
# DE R$ 30.000.000,01 A R$ 100.000.000,00               202
# DE R$ 300.000.000,01 A R$ 500.000.000,00               15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                8
#
#                                           de_faixa_faturamento_estimado_grupo  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                  5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                    278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                   58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                   202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                   15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                    8
#
#                                           vl_faturamento_estimado_aux  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                          5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                            278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                           58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                           202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                           15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                            8
#
#                                           vl_faturamento_estimado_grupo_aux  \
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                                                5
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                  278
# DE R$ 100.000.000,01 A R$ 300.000.000,00                                 58
# DE R$ 30.000.000,01 A R$ 100.000.000,00                                 202
# DE R$ 300.000.000,01 A R$ 500.000.000,00                                 15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS                                  8
#
#                                           qt_filiais
# de_faixa_faturamento_estimado
# ACIMA DE 1 BILHAO DE REAIS                         5
# DE R$ 10.000.000,01 A R$ 30.000.000,00           278
# DE R$ 100.000.000,01 A R$ 300.000.000,00          58
# DE R$ 30.000.000,01 A R$ 100.000.000,00          202
# DE R$ 300.000.000,01 A R$ 500.000.000,00          15
# DE R$ 500.000.000,01 A 1 BILHAO DE REAIS           8
#
# [6 rows x 42 columns]

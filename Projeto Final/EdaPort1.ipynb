# %% [markdown]
# ## Preenchimento dos dados NaN + EDA (Exploratory Data Analysis)
# Criar arquivos "marketok", "portifolio1ok", "portifolio2ok" e "portifolio3ok" com os features que possuem menos de 32% de dados faltantes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import missingno as msno

# %% [markdown]
# ## Dados de Portifolio, trata-se de um determinado nicho de soluções.

# %%
df = pd.read_csv('portfolio1ok.csv', index_col=0)
df.head()
# Out:
#                                                     fl_matriz  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...       True
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...      False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...       True
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...       True
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...       True
#
#                                                              de_natureza_juridica  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          EMPRESARIO INDIVIDUAL
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...          EMPRESARIO INDIVIDUAL
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...          EMPRESARIO INDIVIDUAL
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          EMPRESARIO INDIVIDUAL
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  SOCIEDADE EMPRESARIA LIMITADA
#
#                                                    sg_uf  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...    PI
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...    MA
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...    MA
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...    RN
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...    RN
#
#                                                    natureza_juridica_macro  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                  OUTROS
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                  OUTROS
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                  OUTROS
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                  OUTROS
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  ENTIDADES EMPRESARIAIS
#
#                                                                de_ramo  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  COMERCIO VAREJISTA
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  COMERCIO VAREJISTA
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  COMERCIO VAREJISTA
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  COMERCIO VAREJISTA
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  COMERCIO VAREJISTA
#
#                                                        setor  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  COMERCIO
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  COMERCIO
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  COMERCIO
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  COMERCIO
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  COMERCIO
#
#                                                     idade_empresa_anos  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...            0.646575
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...            6.586301
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...            8.010959
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...           20.863014
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...           18.726027
#
#                                                    idade_emp_cat  fl_me  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          <= 1  False
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...        5 a 10  False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...        5 a 10  False
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          > 20  False
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...       15 a 20  False
#
#                                                     fl_sa    ...      \
# id                                                           ...
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  False    ...
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  False    ...
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  False    ...
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  False    ...
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  False    ...
#
#                                                                    nm_micro_regiao  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...             SAO RAIMUNDO NONATO
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                    MEDIO MEARIM
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  AGLOMERACAO URBANA DE SAO LUIS
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                        UMARIZAL
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                           NATAL
#
#                                                     fl_passivel_iss  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...            False
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...            False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...            False
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...            False
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...            False
#
#                                                     qt_socios qt_socios_pf  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...        1.0          1.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...        NaN          NaN
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...        1.0          1.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...        1.0          1.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...        2.0          2.0
#
#                                                     qt_socios_pj  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...           0.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...           NaN
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...           0.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...           0.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...           0.0
#
#                                                            de_faixa_faturamento_estimado  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...       DE R$ 81.000,01 A R$ 360.000,00
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...       DE R$ 81.000,01 A R$ 360.000,00
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                      ATE R$ 81.000,00
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                      ATE R$ 81.000,00
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  DE R$ 1.500.000,01 A R$ 4.800.000,00
#
#                                                       de_faixa_faturamento_estimado_grupo  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...        DE R$ 81.000,01 A R$ 360.000,00
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...     DE R$ 360.000,01 A R$ 1.500.000,00
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                       ATE R$ 81.000,00
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                       ATE R$ 81.000,00
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  DE R$ 4.800.000,01 A R$ 10.000.000,00
#
#                                                    vl_faturamento_estimado_aux  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                    210000.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                    210000.0
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                     50000.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                     50000.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                   3029140.8
#
#                                                    vl_faturamento_estimado_grupo_aux  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                          210000.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                         1000915.2
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                           50000.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                           50000.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                         5872824.0
#
#                                                    qt_filiais
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...          4
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...          0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...          3
#
# [5 rows x 45 columns]

# %%
# removendo 'qt_socios_pj', 'qt_socios_pf', 'qt_socios', pois há muitos dados faltantes, 
#não há como prever seu campo e influenciam pouco no mercado.
df = df.drop(columns=['qt_socios_pj', 'qt_socios_pf', 'qt_socios'])
df.head()
# Out:
#                                                     fl_matriz  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...       True
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...      False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...       True
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...       True
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...       True
#
#                                                              de_natureza_juridica  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          EMPRESARIO INDIVIDUAL
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...          EMPRESARIO INDIVIDUAL
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...          EMPRESARIO INDIVIDUAL
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          EMPRESARIO INDIVIDUAL
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  SOCIEDADE EMPRESARIA LIMITADA
#
#                                                    sg_uf  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...    PI
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...    MA
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...    MA
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...    RN
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...    RN
#
#                                                    natureza_juridica_macro  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                  OUTROS
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                  OUTROS
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                  OUTROS
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                  OUTROS
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  ENTIDADES EMPRESARIAIS
#
#                                                                de_ramo  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  COMERCIO VAREJISTA
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  COMERCIO VAREJISTA
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  COMERCIO VAREJISTA
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  COMERCIO VAREJISTA
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  COMERCIO VAREJISTA
#
#                                                        setor  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  COMERCIO
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  COMERCIO
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  COMERCIO
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  COMERCIO
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  COMERCIO
#
#                                                     idade_empresa_anos  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...            0.646575
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...            6.586301
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...            8.010959
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...           20.863014
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...           18.726027
#
#                                                    idade_emp_cat  fl_me  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          <= 1  False
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...        5 a 10  False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...        5 a 10  False
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          > 20  False
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...       15 a 20  False
#
#                                                     fl_sa    ...      \
# id                                                           ...
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  False    ...
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...  False    ...
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  False    ...
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...  False    ...
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  False    ...
#
#                                                     fl_simples_irregular  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                 False
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                 False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                 False
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                 False
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                 False
#
#                                                     empsetorcensitariofaixarendapopulacao  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                                 379.96
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                                1865.61
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                                 798.12
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                                 608.47
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                                 880.71
#
#                                                         nm_meso_regiao  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...  SUDOESTE PIAUIENSE
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...   CENTRO MARANHENSE
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...    NORTE MARANHENSE
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...      OESTE POTIGUAR
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...      LESTE POTIGUAR
#
#                                                                    nm_micro_regiao  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...             SAO RAIMUNDO NONATO
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                    MEDIO MEARIM
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...  AGLOMERACAO URBANA DE SAO LUIS
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                        UMARIZAL
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                           NATAL
#
#                                                     fl_passivel_iss  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...            False
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...            False
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...            False
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...            False
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...            False
#
#                                                            de_faixa_faturamento_estimado  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...       DE R$ 81.000,01 A R$ 360.000,00
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...       DE R$ 81.000,01 A R$ 360.000,00
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                      ATE R$ 81.000,00
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                      ATE R$ 81.000,00
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  DE R$ 1.500.000,01 A R$ 4.800.000,00
#
#                                                       de_faixa_faturamento_estimado_grupo  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...        DE R$ 81.000,01 A R$ 360.000,00
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...     DE R$ 360.000,01 A R$ 1.500.000,00
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                       ATE R$ 81.000,00
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                       ATE R$ 81.000,00
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...  DE R$ 4.800.000,01 A R$ 10.000.000,00
#
#                                                    vl_faturamento_estimado_aux  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                    210000.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                    210000.0
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                     50000.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                     50000.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                   3029140.8
#
#                                                    vl_faturamento_estimado_grupo_aux  \
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...                          210000.0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...                         1000915.2
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...                           50000.0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...                           50000.0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...                         5872824.0
#
#                                                    qt_filiais
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255...          0
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b86...          4
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d173360909...          0
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e7...          0
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251...          3
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (555, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 555 entries, dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255be9ea861a9e5841a9 to 970485e6b8abe52d8fb4e0bf060fb6f0f4f8576cb7583d885a8dcac38f506389
# Data columns (total 42 columns):
# fl_matriz                                555 non-null bool
# de_natureza_juridica                     555 non-null object
# sg_uf                                    555 non-null object
# natureza_juridica_macro                  555 non-null object
# de_ramo                                  555 non-null object
# setor                                    555 non-null object
# idade_empresa_anos                       555 non-null float64
# idade_emp_cat                            555 non-null object
# fl_me                                    555 non-null bool
# fl_sa                                    555 non-null bool
# fl_epp                                   555 non-null bool
# fl_mei                                   555 non-null bool
# fl_ltda                                  555 non-null bool
# dt_situacao                              555 non-null object
# fl_st_especial                           555 non-null bool
# fl_email                                 555 non-null bool
# fl_telefone                              555 non-null bool
# fl_rm                                    555 non-null object
# nm_divisao                               555 non-null object
# nm_segmento                              555 non-null object
# fl_spa                                   555 non-null bool
# fl_antt                                  555 non-null bool
# fl_veiculo                               555 non-null bool
# fl_optante_simples                       454 non-null object
# vl_total_veiculos_pesados_grupo          555 non-null int64
# vl_total_veiculos_leves_grupo            555 non-null int64
# fl_optante_simei                         454 non-null object
# sg_uf_matriz                             555 non-null object
# de_saude_tributaria                      544 non-null object
# de_saude_rescencia                       544 non-null object
# nu_meses_rescencia                       508 non-null float64
# de_nivel_atividade                       551 non-null object
# fl_simples_irregular                     555 non-null bool
# empsetorcensitariofaixarendapopulacao    405 non-null float64
# nm_meso_regiao                           491 non-null object
# nm_micro_regiao                          491 non-null object
# fl_passivel_iss                          555 non-null bool
# de_faixa_faturamento_estimado            530 non-null object
# de_faixa_faturamento_estimado_grupo      530 non-null object
# vl_faturamento_estimado_aux              530 non-null float64
# vl_faturamento_estimado_grupo_aux        530 non-null float64
# qt_filiais                               555 non-null int64
# dtypes: bool(14), float64(5), int64(3), object(20)
# memory usage: 133.3+ KB

# %% [markdown]
# # Avaliação de dados faltantes

# %% [markdown]
# ### Percebe-se que este portifolio possui um elevado número de dados faltantes.

# %%
# plot dados faltantes geral
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# plot dados faltantes geral
msno.matrix(df)

# %%
# plot dados faltantes geral
msno.bar(df)

# %%
# checkin what is numerical features
num_feat = df.select_dtypes(include=[np.number])
num_feat.columns
# Out:
# Index(['idade_empresa_anos', 'vl_total_veiculos_pesados_grupo',
#        'vl_total_veiculos_leves_grupo', 'nu_meses_rescencia',
#        'empsetorcensitariofaixarendapopulacao', 'vl_faturamento_estimado_aux',
#        'vl_faturamento_estimado_grupo_aux', 'qt_filiais'],
#       dtype='object')

# %%
# checkin what is categorical features
cat_feat = df.select_dtypes(include=[np.object])
cat_feat.columns
# Out:
# Index(['de_natureza_juridica', 'sg_uf', 'natureza_juridica_macro', 'de_ramo',
#        'setor', 'idade_emp_cat', 'dt_situacao', 'fl_rm', 'nm_divisao',
#        'nm_segmento', 'fl_optante_simples', 'fl_optante_simei', 'sg_uf_matriz',
#        'de_saude_tributaria', 'de_saude_rescencia', 'de_nivel_atividade',
#        'nm_meso_regiao', 'nm_micro_regiao', 'de_faixa_faturamento_estimado',
#        'de_faixa_faturamento_estimado_grupo'],
#       dtype='object')

# %%
# plot dados faltantes para os features numericos
msno.matrix(num_feat)

# %%
# plot dados faltantes para os features numericos
msno.bar(num_feat)

# %%
# plot dados faltantes para os features categoricos
msno.matrix(cat_feat)

# %%
# plot dados faltantes para os features categoricos
msno.bar(cat_feat)

# %% [markdown]
# ## Quantificando dados faltantes
# #### entre numericos e categoricos

# %%
total_num_feat = num_feat.isnull().sum().sort_values(ascending=False)
total_num_feat.sum()
# Out:
# 247

# %%
percent_num_feat = (num_feat.isnull().sum()/num_feat.isnull().count()).sort_values(ascending=False)
round(percent_num_feat.sum(), 2)
# Out:
# 0.45

# %%
missing_data_num_feat = pd.concat([total_num_feat, percent_num_feat], axis=1,join='outer', keys=['Total_Missing_Count', 'Percent_of_Missing'])
missing_data_num_feat.index.name ='features'
missing_data_num_feat.head(5)
# Out:
#                                        Total_Missing_Count  Percent_of_Missing
# features
# empsetorcensitariofaixarendapopulacao                  150            0.270270
# nu_meses_rescencia                                      47            0.084685
# vl_faturamento_estimado_grupo_aux                       25            0.045045
# vl_faturamento_estimado_aux                             25            0.045045
# qt_filiais                                               0            0.000000

# %%
total_cat_feat = cat_feat.isnull().sum().sort_values(ascending=False)
total_cat_feat.sum()
# Out:
# 406

# %%
percent_cat_feat = (cat_feat.isnull().sum()/cat_feat.isnull().count()).sort_values(ascending=False)
round(percent_cat_feat.sum(), 2)
# Out:
# 0.73

# %%
missing_data_cat_feat = pd.concat([total_cat_feat, percent_cat_feat], axis=1,join='outer', keys=['Total_Missing_Count', 'Percent_of_Missing'])
missing_data_cat_feat.index.name ='features'
missing_data_cat_feat.head(10)
# Out:
#                                      Total_Missing_Count  Percent_of_Missing
# features
# fl_optante_simei                                     101            0.181982
# fl_optante_simples                                   101            0.181982
# nm_micro_regiao                                       64            0.115315
# nm_meso_regiao                                        64            0.115315
# de_faixa_faturamento_estimado_grupo                   25            0.045045
# de_faixa_faturamento_estimado                         25            0.045045
# de_saude_rescencia                                    11            0.019820
# de_saude_tributaria                                   11            0.019820
# de_nivel_atividade                                     4            0.007207
# idade_emp_cat                                          0            0.000000

# %% [markdown]
# # Preenchendo dados faltantes

# %% [markdown]
# #### Itens que serão preenchidos - Numéricos

# %%
# empsetorcensitariofaixarendapopulacao	150	0.270270
# inferir utilizando a média deste campo e com mesma localidade (nm_meso_regiao ou nm_micro_regiao)
# empsetorcensitariofaixarendapopulacao: numeric, average income from a sample
# of residents in a census unity (smallest territory area according to IBGE).

# %%
# nu_meses_rescencia	47	0.084685
# utilizar media dos demais
# nu_meses_rescencia:character, number of months since the last update of the most 
# lagged input from saude_tributaria

# %%
# vl_faturamento_estimado_grupo_aux	25	0.045045
# inferir utilizando a média deste campo e com mesmo faturamento grupo (de_faixa_faturamento_estimado_grupo)

# %%
# vl_faturamento_estimado_aux	25	0.045045
# inferir utilizando a média deste campo e com mesmo faturamento (de_faixa_faturamento_estimado)

# %% [markdown]
# #### Itens que serão preenchidos - Categóricos

# %%
# fl_optante_simei	101	0.181982
# inferir utilizando a média deste campo e com mesmo faturamento (de_faixa_faturamento_estimado)

# %%
# fl_optante_simples	101	0.181982
# inferir utilizando a média deste campo e com mesmo faturamento (de_faixa_faturamento_estimado)

# %%
# nm_micro_regiao	64	0.115315
# inferir utilizando este campo e estado (sg_uf)

# %%
# nm_meso_regiao	64	0.115315
# inferir utilizando este campo e estado (sg_uf)

# %%
# de_faixa_faturamento_estimado_grupo	25	0.045045
# inferir usando...

# %%
# de_faixa_faturamento_estimado	25	0.045045
# inferir usando...

# %%
# de_saude_rescencia	11	0.019820
# inferir usando...

# %%
# de_saude_tributaria	11	0.019820
# inferir usando...

# %%
# de_nivel_atividade	4	0.007207
# inferir usando...

# %% [markdown]
# # Avaliação do contexto

# %%
df.columns
# Out:
# Index(['fl_matriz', 'de_natureza_juridica', 'sg_uf', 'natureza_juridica_macro',
#        'de_ramo', 'setor', 'idade_empresa_anos', 'idade_emp_cat', 'fl_me',
#        'fl_sa', 'fl_epp', 'fl_mei', 'fl_ltda', 'dt_situacao', 'fl_st_especial',
#        'fl_email', 'fl_telefone', 'fl_rm', 'nm_divisao', 'nm_segmento',
#        'fl_spa', 'fl_antt', 'fl_veiculo', 'fl_optante_simples',
#        'vl_total_veiculos_pesados_grupo', 'vl_total_veiculos_leves_grupo',
#        'fl_optante_simei', 'sg_uf_matriz', 'de_saude_tributaria',
#        'de_saude_rescencia', 'nu_meses_rescencia', 'de_nivel_atividade',
#        'fl_simples_irregular', 'empsetorcensitariofaixarendapopulacao',
#        'nm_meso_regiao', 'nm_micro_regiao', 'fl_passivel_iss',
#        'de_faixa_faturamento_estimado', 'de_faixa_faturamento_estimado_grupo',
#        'vl_faturamento_estimado_aux', 'vl_faturamento_estimado_grupo_aux',
#        'qt_filiais'],
#       dtype='object')

# %% [raw]
# #### Principais elementos do DataFrame
# (['de_natureza_juridica', 'sg_uf',
#        'de_ramo', 'setor', 'idade_emp_cat', 'fl_me',
#        'fl_sa', 'fl_epp', 'fl_mei', 'fl_ltda', 'dt_situacao', 'fl_st_especial',
#        'fl_email', 'fl_telefone', 'fl_rm', 'nm_divisao', 'nm_segmento',
#        'fl_spa', 'fl_antt', 'fl_veiculo', 'fl_optante_simples',
#        'vl_total_veiculos_pesados_grupo', 'vl_total_veiculos_leves_grupo',
#        'fl_optante_simei', 'sg_uf_matriz', 'de_saude_tributaria',
#        'de_saude_rescencia', 'nu_meses_rescencia', 'de_nivel_atividade',
#        'fl_simples_irregular', 'empsetorcensitariofaixarendapopulacao',
#        'nm_meso_regiao', 'nm_micro_regiao', 'fl_passivel_iss',
#        'de_faixa_faturamento_estimado', 'de_faixa_faturamento_estimado_grupo',
#        'vl_faturamento_estimado_aux', 'vl_faturamento_estimado_grupo_aux',
#        'qt_filiais'],
#       dtype='object')
#
# #### Elementos menos importantes, sugestão de remoção !!
# 'fl_matriz'
# 'natureza_juridica_macro' - já está no natureza_juridica
# 'idade_empresa_anos' - já está no 'idade_emp_cat'
# 'fl_epp' - todos são False

# %%
df.fl_epp.unique()
# Out:
# array([False])

# %%
df.de_ramo.unique()
# Out:
# array(['COMERCIO VAREJISTA', 'BENS DE CONSUMO'], dtype=object)

# %%
df.setor.unique()
# Out:
# array(['COMERCIO', 'INDUSTRIA', 'SERVIÇO'], dtype=object)

# %%
setores = pd.DataFrame(df.groupby('setor').count())
setores
# Out:
#            fl_matriz  de_natureza_juridica  sg_uf  natureza_juridica_macro  \
# setor
# COMERCIO         496                   496    496                      496
# INDUSTRIA         52                    52     52                       52
# SERVIÇO            7                     7      7                        7
#
#            de_ramo  idade_empresa_anos  idade_emp_cat  fl_me  fl_sa  fl_epp  \
# setor
# COMERCIO       496                 496            496    496    496     496
# INDUSTRIA       52                  52             52     52     52      52
# SERVIÇO          7                   7              7      7      7       7
#
#               ...      fl_simples_irregular  \
# setor         ...
# COMERCIO      ...                       496
# INDUSTRIA     ...                        52
# SERVIÇO       ...                         7
#
#            empsetorcensitariofaixarendapopulacao  nm_meso_regiao  \
# setor
# COMERCIO                                     369             441
# INDUSTRIA                                     30              43
# SERVIÇO                                        6               7
#
#            nm_micro_regiao  fl_passivel_iss  de_faixa_faturamento_estimado  \
# setor
# COMERCIO               441              496                            475
# INDUSTRIA               43               52                             48
# SERVIÇO                  7                7                              7
#
#            de_faixa_faturamento_estimado_grupo  vl_faturamento_estimado_aux  \
# setor
# COMERCIO                                   475                          475
# INDUSTRIA                                   48                           48
# SERVIÇO                                      7                            7
#
#            vl_faturamento_estimado_grupo_aux  qt_filiais
# setor
# COMERCIO                                 475         496
# INDUSTRIA                                 48          52
# SERVIÇO                                    7           7
#
# [3 rows x 41 columns]

# %%
temp = pd.DataFrame({'setor':setores.index,'Qtde':setores.fl_matriz})
sns.barplot(x='Qtde',y="setor", data=temp, color="c");

# %%
df.de_natureza_juridica.unique()
# Out:
# array(['EMPRESARIO INDIVIDUAL', 'SOCIEDADE EMPRESARIA LIMITADA',
#        'EMPRESA INDIVIDUAL DE RESPONSABILIDADE LIMITADA DE NATUREZA EMPRESARIA',
#        'SOCIEDADE EMPRESARIA EM NOME COLETIVO',
#        'SOCIEDADE ANONIMA FECHADA', 'SOCIEDADE EM CONTA DE PARTICIPACAO'],
#       dtype=object)

# %%
#df.groupby(['setor','de_natureza_juridica']).count().to_frame()

# %%
df.idade_emp_cat.unique()
# Out:
# array(['<= 1', '5 a 10', '> 20', '15 a 20', '1 a 5', '10 a 15'],
#       dtype=object)

# %%
df.idade_empresa_anos.head(10)
# Out:
# id
# dabe79bec87c88ae04e869bf6bd321ee5e1893cecf66255be9ea861a9e5841a9     0.646575
# 32e5f4e10932153a7ba869cb0386e7e02d49d2461046b866411556d2af150702     6.586301
# a95d6f30bba445bd3d6b0c5b36f865b38ec01d1733609095d359649cfedf15d1     8.010959
# 6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e74532d5040fbc933b8    20.863014
# f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc251dfe8d321e9e6de7f5    18.726027
# f7e2894dce5dbb49662da50c55bcb96cdc3d34188abfe82d54ab6d94e7244d0c     6.238356
# f0c84600cbd2e126ee8314d22816368f33207e723a6ae7ae781582b320c29e4e     9.663014
# d0f8bc5c0e71600d303cacebb3e8e6fd9195322b2c1b15940863e2e980bb17a5     0.495890
# b9b02480a757c3cc5054d6c01e44df62b22ea1328a874374abd49b7197b3d91c     1.161644
# 7d58990ba786a3a26617a8afbf814a9919ab34aa09013a559b2c9d45eb439720     5.309589
# Name: idade_empresa_anos, dtype: float64

# %%
df.idade_empresa_anos.mean()
# Out:
# 10.13924719239788

# %%
df.idade_empresa_anos.hist()

# %%
sns.boxplot(df.idade_empresa_anos)

# %%
sns.boxplot(x='idade_empresa_anos', y='setor', data=df)

# %%
de_faixa_fatur_est = pd.DataFrame(df.groupby('de_faixa_faturamento_estimado').count())
de_faixa_fatur_est
# Out:
#                                         fl_matriz  de_natureza_juridica  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                              144                   144
# DE R$ 1.500.000,01 A R$ 4.800.000,00           16                    16
# DE R$ 10.000.000,01 A R$ 30.000.000,00          1                     1
# DE R$ 360.000,01 A R$ 1.500.000,00             41                    41
# DE R$ 4.800.000,01 A R$ 10.000.000,00           1                     1
# DE R$ 81.000,01 A R$ 360.000,00               325                   325
# SEM INFORMACAO                                  2                     2
#
#                                         sg_uf  natureza_juridica_macro  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                          144                      144
# DE R$ 1.500.000,01 A R$ 4.800.000,00       16                       16
# DE R$ 10.000.000,01 A R$ 30.000.000,00      1                        1
# DE R$ 360.000,01 A R$ 1.500.000,00         41                       41
# DE R$ 4.800.000,01 A R$ 10.000.000,00       1                        1
# DE R$ 81.000,01 A R$ 360.000,00           325                      325
# SEM INFORMACAO                              2                        2
#
#                                         de_ramo  setor  idade_empresa_anos  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                            144    144                 144
# DE R$ 1.500.000,01 A R$ 4.800.000,00         16     16                  16
# DE R$ 10.000.000,01 A R$ 30.000.000,00        1      1                   1
# DE R$ 360.000,01 A R$ 1.500.000,00           41     41                  41
# DE R$ 4.800.000,01 A R$ 10.000.000,00         1      1                   1
# DE R$ 81.000,01 A R$ 360.000,00             325    325                 325
# SEM INFORMACAO                                2      2                   2
#
#                                         idade_emp_cat  fl_me  fl_sa  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                  144    144    144
# DE R$ 1.500.000,01 A R$ 4.800.000,00               16     16     16
# DE R$ 10.000.000,01 A R$ 30.000.000,00              1      1      1
# DE R$ 360.000,01 A R$ 1.500.000,00                 41     41     41
# DE R$ 4.800.000,01 A R$ 10.000.000,00               1      1      1
# DE R$ 81.000,01 A R$ 360.000,00                   325    325    325
# SEM INFORMACAO                                      2      2      2
#
#                                            ...      de_nivel_atividade  \
# de_faixa_faturamento_estimado              ...
# ATE R$ 81.000,00                           ...                     144
# DE R$ 1.500.000,01 A R$ 4.800.000,00       ...                      16
# DE R$ 10.000.000,01 A R$ 30.000.000,00     ...                       1
# DE R$ 360.000,01 A R$ 1.500.000,00         ...                      41
# DE R$ 4.800.000,01 A R$ 10.000.000,00      ...                       1
# DE R$ 81.000,01 A R$ 360.000,00            ...                     325
# SEM INFORMACAO                             ...                       1
#
#                                         fl_simples_irregular  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                         144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                      16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     1
# DE R$ 360.000,01 A R$ 1.500.000,00                        41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                      1
# DE R$ 81.000,01 A R$ 360.000,00                          325
# SEM INFORMACAO                                             2
#
#                                         empsetorcensitariofaixarendapopulacao  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                          122
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                       14
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                      0
# DE R$ 360.000,01 A R$ 1.500.000,00                                         35
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                       0
# DE R$ 81.000,01 A R$ 360.000,00                                           225
# SEM INFORMACAO                                                              2
#
#                                         nm_meso_regiao  nm_micro_regiao  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                   128              128
# DE R$ 1.500.000,01 A R$ 4.800.000,00                14               14
# DE R$ 10.000.000,01 A R$ 30.000.000,00               1                1
# DE R$ 360.000,01 A R$ 1.500.000,00                  33               33
# DE R$ 4.800.000,01 A R$ 10.000.000,00                1                1
# DE R$ 81.000,01 A R$ 360.000,00                    288              288
# SEM INFORMACAO                                       2                2
#
#                                         fl_passivel_iss  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                    144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                 16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                1
# DE R$ 360.000,01 A R$ 1.500.000,00                   41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                 1
# DE R$ 81.000,01 A R$ 360.000,00                     325
# SEM INFORMACAO                                        2
#
#                                         de_faixa_faturamento_estimado_grupo  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                        144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                     16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                    1
# DE R$ 360.000,01 A R$ 1.500.000,00                                       41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                     1
# DE R$ 81.000,01 A R$ 360.000,00                                         325
# SEM INFORMACAO                                                            2
#
#                                         vl_faturamento_estimado_aux  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                             16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                            1
# DE R$ 360.000,01 A R$ 1.500.000,00                               41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                             1
# DE R$ 81.000,01 A R$ 360.000,00                                 325
# SEM INFORMACAO                                                    2
#
#                                         vl_faturamento_estimado_grupo_aux  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                      144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                   16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                  1
# DE R$ 360.000,01 A R$ 1.500.000,00                                     41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                   1
# DE R$ 81.000,01 A R$ 360.000,00                                       325
# SEM INFORMACAO                                                          2
#
#                                         qt_filiais
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                               144
# DE R$ 1.500.000,01 A R$ 4.800.000,00            16
# DE R$ 10.000.000,01 A R$ 30.000.000,00           1
# DE R$ 360.000,01 A R$ 1.500.000,00              41
# DE R$ 4.800.000,01 A R$ 10.000.000,00            1
# DE R$ 81.000,01 A R$ 360.000,00                325
# SEM INFORMACAO                                   2
#
# [7 rows x 41 columns]

# %%
de_faixa_fatur_est = pd.DataFrame(df.groupby('de_faixa_faturamento_estimado').count())
de_faixa_fatur_est
# Out:
#                                         fl_matriz  de_natureza_juridica  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                              144                   144
# DE R$ 1.500.000,01 A R$ 4.800.000,00           16                    16
# DE R$ 10.000.000,01 A R$ 30.000.000,00          1                     1
# DE R$ 360.000,01 A R$ 1.500.000,00             41                    41
# DE R$ 4.800.000,01 A R$ 10.000.000,00           1                     1
# DE R$ 81.000,01 A R$ 360.000,00               325                   325
# SEM INFORMACAO                                  2                     2
#
#                                         sg_uf  natureza_juridica_macro  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                          144                      144
# DE R$ 1.500.000,01 A R$ 4.800.000,00       16                       16
# DE R$ 10.000.000,01 A R$ 30.000.000,00      1                        1
# DE R$ 360.000,01 A R$ 1.500.000,00         41                       41
# DE R$ 4.800.000,01 A R$ 10.000.000,00       1                        1
# DE R$ 81.000,01 A R$ 360.000,00           325                      325
# SEM INFORMACAO                              2                        2
#
#                                         de_ramo  setor  idade_empresa_anos  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                            144    144                 144
# DE R$ 1.500.000,01 A R$ 4.800.000,00         16     16                  16
# DE R$ 10.000.000,01 A R$ 30.000.000,00        1      1                   1
# DE R$ 360.000,01 A R$ 1.500.000,00           41     41                  41
# DE R$ 4.800.000,01 A R$ 10.000.000,00         1      1                   1
# DE R$ 81.000,01 A R$ 360.000,00             325    325                 325
# SEM INFORMACAO                                2      2                   2
#
#                                         idade_emp_cat  fl_me  fl_sa  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                  144    144    144
# DE R$ 1.500.000,01 A R$ 4.800.000,00               16     16     16
# DE R$ 10.000.000,01 A R$ 30.000.000,00              1      1      1
# DE R$ 360.000,01 A R$ 1.500.000,00                 41     41     41
# DE R$ 4.800.000,01 A R$ 10.000.000,00               1      1      1
# DE R$ 81.000,01 A R$ 360.000,00                   325    325    325
# SEM INFORMACAO                                      2      2      2
#
#                                            ...      de_nivel_atividade  \
# de_faixa_faturamento_estimado              ...
# ATE R$ 81.000,00                           ...                     144
# DE R$ 1.500.000,01 A R$ 4.800.000,00       ...                      16
# DE R$ 10.000.000,01 A R$ 30.000.000,00     ...                       1
# DE R$ 360.000,01 A R$ 1.500.000,00         ...                      41
# DE R$ 4.800.000,01 A R$ 10.000.000,00      ...                       1
# DE R$ 81.000,01 A R$ 360.000,00            ...                     325
# SEM INFORMACAO                             ...                       1
#
#                                         fl_simples_irregular  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                         144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                      16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                     1
# DE R$ 360.000,01 A R$ 1.500.000,00                        41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                      1
# DE R$ 81.000,01 A R$ 360.000,00                          325
# SEM INFORMACAO                                             2
#
#                                         empsetorcensitariofaixarendapopulacao  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                          122
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                       14
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                      0
# DE R$ 360.000,01 A R$ 1.500.000,00                                         35
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                       0
# DE R$ 81.000,01 A R$ 360.000,00                                           225
# SEM INFORMACAO                                                              2
#
#                                         nm_meso_regiao  nm_micro_regiao  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                   128              128
# DE R$ 1.500.000,01 A R$ 4.800.000,00                14               14
# DE R$ 10.000.000,01 A R$ 30.000.000,00               1                1
# DE R$ 360.000,01 A R$ 1.500.000,00                  33               33
# DE R$ 4.800.000,01 A R$ 10.000.000,00                1                1
# DE R$ 81.000,01 A R$ 360.000,00                    288              288
# SEM INFORMACAO                                       2                2
#
#                                         fl_passivel_iss  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                    144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                 16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                1
# DE R$ 360.000,01 A R$ 1.500.000,00                   41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                 1
# DE R$ 81.000,01 A R$ 360.000,00                     325
# SEM INFORMACAO                                        2
#
#                                         de_faixa_faturamento_estimado_grupo  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                        144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                     16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                    1
# DE R$ 360.000,01 A R$ 1.500.000,00                                       41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                     1
# DE R$ 81.000,01 A R$ 360.000,00                                         325
# SEM INFORMACAO                                                            2
#
#                                         vl_faturamento_estimado_aux  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                             16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                            1
# DE R$ 360.000,01 A R$ 1.500.000,00                               41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                             1
# DE R$ 81.000,01 A R$ 360.000,00                                 325
# SEM INFORMACAO                                                    2
#
#                                         vl_faturamento_estimado_grupo_aux  \
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                                                      144
# DE R$ 1.500.000,01 A R$ 4.800.000,00                                   16
# DE R$ 10.000.000,01 A R$ 30.000.000,00                                  1
# DE R$ 360.000,01 A R$ 1.500.000,00                                     41
# DE R$ 4.800.000,01 A R$ 10.000.000,00                                   1
# DE R$ 81.000,01 A R$ 360.000,00                                       325
# SEM INFORMACAO                                                          2
#
#                                         qt_filiais
# de_faixa_faturamento_estimado
# ATE R$ 81.000,00                               144
# DE R$ 1.500.000,01 A R$ 4.800.000,00            16
# DE R$ 10.000.000,01 A R$ 30.000.000,00           1
# DE R$ 360.000,01 A R$ 1.500.000,00              41
# DE R$ 4.800.000,01 A R$ 10.000.000,00            1
# DE R$ 81.000,01 A R$ 360.000,00                325
# SEM INFORMACAO                                   2
#
# [7 rows x 41 columns]
